# %% [markdown]
# <a href="https://colab.research.google.com/github/shanusushmita/CS4973-Applied-Multilingual-Systems/blob/main/Week_5%2C_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pseudo-code for your lab work
import pandas as pd
import json
import spacy # A great library for linguistic processing

# 1. Load your generated data from a JSONL file
data = []
with open('generated_dialogues.jsonl', 'r') as f:
    for line in f:
        data.append(json.loads(line))

df = pd.DataFrame(data)

# 2. Add a word_count column
df['word_count'] = df['text'].apply(lambda x: len(x.split()))

# 3. Add a tokenized_text column
df['tokens'] = df['text'].apply(lambda x: x.split())

# 4. (Challenge) POS Tagging with spaCy
# You'll need to load a model for your language pair
# For example, for English: nlp = spacy.load("en_core_web_sm")
# You'll have to find the right model for your language pair!
# df['pos_tags'] = df['text'].apply(lambda x: [token.pos_ for token in nlp(x)])

print(df.head())
